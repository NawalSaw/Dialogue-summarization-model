# %%
from datasets import load_dataset

dataset = load_dataset("knkarthick/samsum")

train_sets = dataset["train"]

highest_lenth=0
index=0
for i in range(len(train_sets["summary"])):
    if (len(train_sets["summary"][i]) > 0):
        highest_lenth = len(train_sets["summary"][i])
        index=i

print(highest_lenth, index)
# Out:
# 235 14730
